# %%
import dtale
import plotly.express as px
import plotly
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import the dataset

# %%
energy_data = pd.read_csv(r'D:\Study Materials\Projects\energy_production.csv', sep=';')
energy_data
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0            9.59           38.56       1017.01       60.10             481.30
# 1           12.04           42.34       1019.72       94.67             465.36
# 2           13.87           45.08       1024.42       81.69             465.48
# 3           13.72           54.30       1017.89       79.08             467.05
# 4           15.14           49.64       1023.78       75.00             463.58
# ...           ...             ...           ...         ...                ...
# 9563        17.10           49.69       1005.53       81.82             457.32
# 9564        24.73           65.34       1015.42       52.80             446.92
# 9565        30.44           56.24       1005.19       56.24             429.34
# 9566        23.00           66.05       1020.61       80.29             421.57
# 9567        17.75           49.25       1020.86       63.67             454.41
#
# [9568 rows x 5 columns]

# %%
conda install -c plotly python-kaleido
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
d = dtale.show(energy_data)
d
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-EO3K1OEI:40000/dtale/iframe/4"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Exception occurred while processing request: 'NoneType' object is not subscriptable
# Traceback (most recent call last):
#   File "C:\Users\91890\anaconda3\lib\site-packages\dtale\views.py", line 114, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "C:\Users\91890\anaconda3\lib\site-packages\dtale\views.py", line 2923, in get_scatter
#     y_cols = [cols[1], idx_col]
# TypeError: 'NoneType' object is not subscriptable
# 2022-02-21 22:55:32,837 - ERROR    - Exception occurred while processing request: 'NoneType' object is not subscriptable
# Traceback (most recent call last):
#   File "C:\Users\91890\anaconda3\lib\site-packages\dtale\views.py", line 114, in _handle_exceptions
#     return func(*args, **kwargs)
# ...

# %%
fig = px.box(energy_data,y='amb_pressure')
fig.show()
# Out:
# <div>                            <div id="a017e0ab-2033-4637-a85f-11ba68fc2573" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a017e0ab-2033-4637-a85f-11ba68fc2573")) {                    Plotly.newPlot(                        "a017e0ab-2033-4637-a85f-11ba68fc2573",                        [{"alignmentgroup":"True","hovertemplate":"amb_pressure=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[1017.01,1019.72,1024.42,1017.89,1023.78,1006.41,1009.88,1015.89,1011.14,1002.47,1019.02,1017.41,1013.68,1006.09,1009.4,1007.55,1007.5,1009.69,1007.28,1014.76,1015.28,1005.56,1007.26,1013.1,1017.19,1017.65,1013.24,1013.85,1009.76,1017.02,10
# ...

# %%
plotly.offline.iplot(fig, filename='filename.png',image='png')# For Downloading the image as png
# Out:
# <div>                            <div id="39c18ac2-9ea5-42e9-a93b-f99b8bde9115" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39c18ac2-9ea5-42e9-a93b-f99b8bde9115")) {                    Plotly.newPlot(                        "39c18ac2-9ea5-42e9-a93b-f99b8bde9115",                        [{"alignmentgroup":"True","hovertemplate":"amb_pressure=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[1017.01,1019.72,1024.42,1017.89,1023.78,1006.41,1009.88,1015.89,1011.14,1002.47,1019.02,1017.41,1013.68,1006.09,1009.4,1007.55,1007.5,1009.69,1007.28,1014.76,1015.28,1005.56,1007.26,1013.1,1017.19,1017.65,1013.24,1013.85,1009.76,1017.02,10
# ...

# %%
fig1= px.box(energy_data,y='r_humidity')
fig1.show()
# Out:
# <div>                            <div id="243df3d1-2d6d-4584-a9e6-897144aa981a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("243df3d1-2d6d-4584-a9e6-897144aa981a")) {                    Plotly.newPlot(                        "243df3d1-2d6d-4584-a9e6-897144aa981a",                        [{"alignmentgroup":"True","hovertemplate":"r_humidity=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[60.1,94.67,81.69,79.08,75.0,83.06,81.56,68.85,55.78,85.39,69.98,72.31,70.66,42.17,48.63,72.76,76.21,64.66,78.47,47.06,88.22,66.53,60.55,84.74,87.45,86.29,91.55,55.95,75.36,82.4,28.16,93.25,86.21,85.39,66.83,85.14,94.85,66.26,69.44,69.02,74.3
# ...

# %%
plotly.offline.iplot(fig1, filename='relative_humidity_boxplot.png',image='png') # For Downloading the image as png
# Out:
# <div>                            <div id="67279736-28a1-417a-8cd4-af69e7c08454" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67279736-28a1-417a-8cd4-af69e7c08454")) {                    Plotly.newPlot(                        "67279736-28a1-417a-8cd4-af69e7c08454",                        [{"alignmentgroup":"True","hovertemplate":"r_humidity=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[60.1,94.67,81.69,79.08,75.0,83.06,81.56,68.85,55.78,85.39,69.98,72.31,70.66,42.17,48.63,72.76,76.21,64.66,78.47,47.06,88.22,66.53,60.55,84.74,87.45,86.29,91.55,55.95,75.36,82.4,28.16,93.25,86.21,85.39,66.83,85.14,94.85,66.26,69.44,69.02,74.3
# ...

# %%
energy_data.head(5)
# Out:
#    temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0         9.59           38.56       1017.01       60.10             481.30
# 1        12.04           42.34       1019.72       94.67             465.36
# 2        13.87           45.08       1024.42       81.69             465.48
# 3        13.72           54.30       1017.89       79.08             467.05
# 4        15.14           49.64       1023.78       75.00             463.58

# %%
fig2= px.box(energy_data,y='temperature')
fig2.show()
# Out:
# <div>                            <div id="31cd56ce-0928-46aa-a2cf-b3f97a24cf0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31cd56ce-0928-46aa-a2cf-b3f97a24cf0f")) {                    Plotly.newPlot(                        "31cd56ce-0928-46aa-a2cf-b3f97a24cf0f",                        [{"alignmentgroup":"True","hovertemplate":"temperature=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[9.59,12.04,13.87,13.72,15.14,23.63,22.99,12.85,29.88,23.22,9.02,26.12,16.66,29.56,30.0,30.39,20.88,28.14,18.86,31.85,17.47,25.04,29.01,22.36,13.98,19.6,12.51,22.76,19.65,14.78,33.94,7.55,5.62,20.76,18.44,12.78,8.95,31.95,9.95,22.25,23.95,32
# ...

# %%
plotly.offline.iplot(fig2, filename='relative_humidity_boxplot.png',image='png') # For Downloading the image as png
# Out:
# <div>                            <div id="b80b2a3a-d057-418e-b80a-dc8a05bbfe90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b80b2a3a-d057-418e-b80a-dc8a05bbfe90")) {                    Plotly.newPlot(                        "b80b2a3a-d057-418e-b80a-dc8a05bbfe90",                        [{"alignmentgroup":"True","hovertemplate":"temperature=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[9.59,12.04,13.87,13.72,15.14,23.63,22.99,12.85,29.88,23.22,9.02,26.12,16.66,29.56,30.0,30.39,20.88,28.14,18.86,31.85,17.47,25.04,29.01,22.36,13.98,19.6,12.51,22.76,19.65,14.78,33.94,7.55,5.62,20.76,18.44,12.78,8.95,31.95,9.95,22.25,23.95,32
# ...

# %%
fig3= px.box(energy_data,y='exhaust_vacuum')
fig3.show()
# Out:
# <div>                            <div id="5c41385f-0186-4e41-ab7b-0f082fad9d04" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c41385f-0186-4e41-ab7b-0f082fad9d04")) {                    Plotly.newPlot(                        "5c41385f-0186-4e41-ab7b-0f082fad9d04",                        [{"alignmentgroup":"True","hovertemplate":"exhaust_vacuum=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[38.56,42.34,45.08,54.3,49.64,60.93,61.02,40.0,68.08,66.56,38.08,75.6,36.71,52.84,61.5,70.98,47.45,61.47,46.48,68.3,63.31,51.95,70.32,59.44,40.24,59.21,43.67,58.96,44.89,38.58,74.67,42.85,41.38,59.04,39.72,41.04,43.13,70.8,41.82,59.8,58.7
# ...

# %%
plotly.offline.iplot(fig3, filename='exhaust_vaccum_boxplot.png',image='png') # For Downloading the image as png
# Out:
# <div>                            <div id="1659bf45-89fc-4b3d-a8ab-0915dab72f62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1659bf45-89fc-4b3d-a8ab-0915dab72f62")) {                    Plotly.newPlot(                        "1659bf45-89fc-4b3d-a8ab-0915dab72f62",                        [{"alignmentgroup":"True","hovertemplate":"exhaust_vacuum=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[38.56,42.34,45.08,54.3,49.64,60.93,61.02,40.0,68.08,66.56,38.08,75.6,36.71,52.84,61.5,70.98,47.45,61.47,46.48,68.3,63.31,51.95,70.32,59.44,40.24,59.21,43.67,58.96,44.89,38.58,74.67,42.85,41.38,59.04,39.72,41.04,43.13,70.8,41.82,59.8,58.7
# ...

# %%
fig4= px.box(energy_data,y='energy_production')

# %%
plotly.offline.iplot(fig4, filename='energy_production_boxplot.png',image='png') # For Downloading the image as png
# Out:
# <div>                            <div id="3f64bc8e-8cbe-46eb-96b7-bfc08d78357f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f64bc8e-8cbe-46eb-96b7-bfc08d78357f")) {                    Plotly.newPlot(                        "3f64bc8e-8cbe-46eb-96b7-bfc08d78357f",                        [{"alignmentgroup":"True","hovertemplate":"energy_production=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[481.3,465.36,465.48,467.05,463.58,439.9,440.85,463.74,429.33,437.11,478.32,439.68,466.07,436.46,435.6,435.48,449.34,435.35,452.0,428.72,450.68,449.45,429.23,446.75,467.2,449.23,471.96,454.05,451.35,460.54,427.98,484.93,490.83,448.92,4
# ...
